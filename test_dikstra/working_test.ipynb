# %%
import pulp 
import heapq
import folium
import math

import networkx as nx
import pandas as pd

from geopy.distance import geodesic

# %% [markdown]
# # Imports

# %%
df_source = pd.read_csv('/Users/samuele/Desktop/我/CC/FoliaStream/test_dikstra/source.csv')
df_sink = pd.read_csv('/Users/samuele/Desktop/我/CC/FoliaStream/test_dikstra/sink.csv')

# %%
df_source['id'] = df_source['id'].astype(int)
df_sink['id'] = df_sink['id'].astype(int)
df_source = df_source.set_index(df_source['id'])
df_sink = df_sink.set_index(df_sink['id'])

# %%
# Inputs

transport_cost_0_50000 = 2.5
transport_cost_50000_100000 = 1.5
transport_cost_100000_250000 = 0.9
transport_cost_250000_500000 = 0.6
transport_cost_500000_1000000 = 0.4
transport_cost_1000000_2000000 = 0.3
transport_cost_2000000_999999999 = 0.2

emission_cost = 100

lat_max = max(max(df_sink['latitude']),max(df_source['lat']))
lon_max = max(max(df_sink['longitude']),max(df_source['lon']))
lat_min = min(min(df_sink['latitude']),min(df_source['lat']))
lon_min = min(min(df_sink['longitude']),min(df_source['lon']))

# %% [markdown]
# # Support functions

# %%
def create_fully_connected_graph(df_source, df_sink):

    # Init graph
    G = nx.DiGraph()

    # Add source nodes
    for idx, row in df_source.iterrows():
        node_id = f"source_{idx}"
        G.add_node(node_id,
                   pos=(row['lat'], row['lon']),
                   type='source')
    
    # Add sink nodes
    for idx, row in df_sink.iterrows():
        node_id = f"sink_{idx}"
        G.add_node(node_id,
                   pos=(row['longitude'], row['latitude']),
                   type='sink')
    
    # Create fully connected graph with geodesic distances 
    for i, (i_id, i_data) in enumerate(G.nodes(data=True)):
        i_lat = df_source.loc[int(i_id.split('_')[1])]['lat'] if 'source' in i_id else df_sink.loc[int(i_id.split('_')[1])]['latitude']
        i_lon = df_source.loc[int(i_id.split('_')[1])]['lon'] if 'source' in i_id else df_sink.loc[int(i_id.split('_')[1])]['longitude']

        for j,(j_id, j_data) in enumerate(G.nodes(data=True)):
            if i_id != j_id: # Avoid self loops
                j_pos = j_data['pos']
                j_lat = df_source.loc[int(j_id.split('_')[1])]['lat'] if 'source' in j_id else df_sink.loc[int(j_id.split('_')[1])]['latitude']
                j_lon = df_source.loc[int(j_id.split('_')[1])]['lon'] if 'source' in j_id else df_sink.loc[int(j_id.split('_')[1])]['longitude']

                # Calculate geodesic distance
                weight = geodesic((i_lat, i_lon), (j_lat, j_lon)).kilometers
                G.add_edge(i_id, j_id, weight=weight)
    return G

# %%
def path_dependent_dijkstra(G, source, target):

    # Track distance, paths, and hop counts
    distances = {node: float('infinity') for node in G.nodes()}
    distances[source] = 0
    previous_nodes = {node: None for node in G.nodes()}
    hop_counts = {node:0 for node in G.nodes()}
    hop_counts[source] = 1 # start with 1 node in the path

    # Priority queue for nodes to visti: (adjusted_distance, node)
    priority_queue = [(0,source)]

    while priority_queue:
        current_distance, current_node = heapq.heappop(priority_queue)

        # Stop if reach target
        if current_node == target:
            break
    
        # Skip if already found better path
        if current_distance > distances[current_node]:
            continue

        # Check all neighbors
        for neighbor in G.neighbors(current_node):

            # Raw edge weight
            edge_weight = G[current_node][neighbor]['weight']

            # Adjust weight based on hop count (divide by hop count)
            adjusted_weight = edge_weight / hop_counts[current_node]

            # Calculate new distances
            distance = distances[current_node] + adjusted_weight

            # Update if better path found
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous_nodes[neighbor] = current_node
                hop_counts[neighbor] = hop_counts[current_node] + 1
                heapq.heappush(priority_queue, (distance, neighbor))
    
    # Reconstruct path
    path = []
    current_node = target
    while current_node is not None:
        path.insert(0, current_node)
        current_node = previous_nodes[current_node]

    # Calculate actual distance (not adjusted) for the found path 
    actual_distance = 0 
    for i in range(len(path)-1):
        actual_distance += G[path[i]][path[i+1]]['weight']
    
    return path, distances[target], actual_distance, hop_counts[target]

# %% [markdown]
# # Step 1. Generate Dijkstra paths for all source-sink pairs

# %%
def generate_all_paths(df_source, df_sink, graph):

    path_registry = {}

    for i, rsource in df_source.iterrows():
        source_node = f'source_{i}'
        for j, rsink in df_sink.iterrows():
            sink_node = f'sink_{j}'

            # Get path using path-dependent Dijkstra
            path, adjusted_distance, actual_distance, hop_count = path_dependent_dijkstra(graph, source_node, sink_node)

            # Register path with its details
            path_registry[(i,j)] = {
                'path':path,
                'adjusted_distance':adjusted_distance,
                'actual_distance':actual_distance,
                'hop_count':hop_count,
                'source_id':f'source_id_{i}',
                'sink_id':f'sink_id_{j}'
            }
            
    return path_registry

# %% [markdown]
# # Step 2. Create MCF model with path based flow variables

# %%
def create_path_based_mcf_model(df_source, df_sink, path_registry):

    # Init problem
    prob = pulp.LpProblem("PathBasedMCF", pulp.LpMinimize)

    # Create flow variables for each path 
    path_vars = {}
    for (i,j), path_info in path_registry.items():
        var_name = f'Flow_from_{i}_to_{j}'
        path_vars[(i,j)] = pulp.LpVariable(var_name, 0, None, pulp.LpContinuous)

    # Create flow variables for emissions to atmosphere
    atmo_vars = {}
    for i,row in df_source.iterrows():
        var_name = f"Flow_from_{i}_to_atmo"
        atmo_vars[i] = pulp.LpVariable(var_name, 0, None, pulp.LpContinuous)

    # Cost function: placewise linear segments for path-based transportation costs
    path_segment_vars = {}

    for (i,j), path_info in path_registry.items():
        segments = []
        # The scaled distance cost uses actual_distance froim the path
        distance = path_info['actual_distance']

        # Cost segments using path distnace
        cost_segments = [
            (0,50000, transport_cost_0_50000 * distance),
            (50000,100000, transport_cost_50000_100000 * distance),
            (100000,250000, transport_cost_100000_250000 * distance),
            (250000,500000, transport_cost_250000_500000 * distance),
            (500000,1000000, transport_cost_500000_1000000 * distance),
            (1000000,2000000, transport_cost_1000000_2000000 * distance),
            (2000000,999999999, transport_cost_2000000_999999999 * distance),
        ]

        for i_seg, (start, end, slope) in enumerate(cost_segments):
            var = pulp.LpVariable(f'Segment_path_{i}_{j}_{i_seg}', 0, end-start, pulp.LpContinuous)
            segments.append((var, start, end, slope))
        
        path_segment_vars[(i,j)] = segments

    # Same for atmosphere emission costs
    atmo_segment_vars = {}
    for i,row in df_source.iterrows():
        var = pulp.LpVariable(f'Segment_atmo_{i}', 0, 999999999999999999999999999, pulp.LpContinuous)
        atmo_segment_vars[i] = [(var, 0, 999999999999999999999999999, emission_cost)]

    # Objective: Minimize total cost acrtoss all paths and emissions

    prob += pulp.lpSum([var * slope for (i,j) in path_registry for var, start, end, slope in path_segment_vars[(i,j)]] + 
                       [var * slope for i in df_source.index for var, start, end, slope in atmo_segment_vars[i]]), "TotalCost"
    
    # Constraint: all source emission must be extracted from source
    print(atmo_vars)
    for i, rsource in df_source.iterrows():
        prob += (pulp.lpSum([path_vars[(i,j)] for j in df_sink.index if (i,j) in path_vars]) + 
                 atmo_vars[i] == rsource['emission']), f'source_id_{i}_flow_conservation'
        
    # Constraint: link flow variables to their piecewise segments 
    for (i,j) in path_registry:
        prob += path_vars[(i,j)] == pulp.lpSum([var for var, start, end, slope in path_segment_vars[(i,j)]]), f"Piecewise_path_{i}_{j}"
    
    for i, row in df_source.iterrows():
        prob += atmo_vars[i] == pulp.lpSum([var for var, start, end, slope, in atmo_segment_vars[i]]), f'Piecewise_atmo_{i}'
    
    # Optional: capacity constraints for paths
    for (i,j) in path_registry:
        prob += path_vars[(i,j)] <= 10000000000 #000000
    
    return prob, path_vars, atmo_vars

# %% [markdown]
# # Step 3. Visualize on map

# %%
def visualize_flow_map(map_obj, df_source, df_sink, path_registry, path_vars):

    # Dictionary to track cumulative flow on each edge
    edge_flows = {}

    # First calculate cumulative flow on each edge
    for (i,j), path_info in path_registry.items():
        flow_amount = path_vars[(i,j)].varValue

        if flow_amount > 0:
            path = path_info['path']

            # Process each edge in the path
            for k in range(len(path) - 1):
                edge = (path[k], path[k+1])

                # Add flow to this edge
                if edge in edge_flows:
                    edge_flows[edge] += flow_amount
                else:
                    edge_flows[edge] = flow_amount
    
    # Visualize each edge with its cumulative flow
    for edge, flow in edge_flows.items():
        start_node, end_node = edge

        # Get coordinates for start node
        if "source" in start_node:
            idx = int(start_node.split('_')[1])
            start_lat = df_source.loc[idx]['lat'] ####
            start_lon = df_source.loc[idx]['lon'] ####
        else:
            idx = int(end_node.split('_')[1])
            start_lat = df_sink.loc[idx]['latitude']
            start_lon = df_sink.loc[idx]['longitude']
        
        # Get coordinates for end node
        if "source" in end_node:
            idx = int(end_node.split('_')[1])
            end_lat = df_source.loc[idx]['lat']
            end_lon = df_source.loc[idx]['lon']
        else:
            idx = int(end_node.split('_')[1])
            end_lat = df_sink.loc[idx]['latitude']
            end_lon = df_sink.loc[idx]['longitude']
        
        # Calculate edge weight with cumulative flow tooltip
        weight = 2 + (flow / 1000000) # Adjust as needed

        folium.PolyLine(
            locations=[(start_lat, start_lon), (end_lat, end_lon)],
            weight=weight,
            color='green',
            opacity=0.7,
            tooltip=f"Flow: {flow:.2f} units \n{start_node} ==> {end_node}"
        ).add_to(map_obj)
    
    # Add detail information as a control panel
    html_content = """
    <div style="position: fixed;
                bottom: 50px; right: 50px; width: 280px;
                border:2px solid grey; z-index:9999; font-size:12px;
                background-color:white; padding:10px;
                opacity:0.8;">
    <h4>Edge Details</h4>
    <table>
        <tr><th>Edge</th><th>Flow</th></tr>
    """

    # Sort edges by flow amount for better readability
    sorted_edges = sorted(edge_flows.items(), key=lambda x: x[1], reverse=True)

    for edge, flow in sorted_edges:
        start, end = edge
        html_content += f"<tr><td>{start} ==> {end}</td><td>{flow:.2f}</td></tr>"

    html_content += """
    </table>
    </div>
    """
        
    # Add the HTML content to the map
    folium.Element(html_content).add_to(map_obj)

    return map_obj

# %% [markdown]
# # Execute

# %%
def main():
    
    # Create graph
    graph = create_fully_connected_graph(df_source, df_sink)

    # Generate all paths
    path_registry = generate_all_paths(df_source, df_sink, graph)

    # Create and solve the MCF model
    prob, path_vars, atmo_vars = create_path_based_mcf_model(df_source, df_sink, path_registry)
    prob.solve()

    # Check solution status
    status = pulp.LpStatus[prob.status]
    print("Status: ", status)

    if status == 'Infeasible':
        print("The model is infeasible.")
    else:
        # Print results
        print("\n Flow Results:")
        for (i,j) in path_registry:
            flow = path_vars[(i,j)].varValue
            if flow > 0:
                path = path_registry[(i,j)]['path']
                print(f"Flow from source_{i} to sink_{j}: {flow:.2f} tons")
                print(f"Path: {'==>'.join(path)}")
                print(f"Distance: {path_registry[(i,j)]['actual_distance']:.2f} km")
                print()

        # Print atmospheric emissions
        for i, row in df_source.iterrows():
            flow = atmo_vars[i].varValue
            if flow>0:
                print(f"Emissions from source_{i} to atmosphere: {flow:.2f} units")

        print("\n Total Cost:", pulp.value(prob.objective))

        # Visualize results
        map = folium.Map(location=((lat_max + lat_min)/2, (lon_max + lon_min)/2), zoom_start=6)

        # Add markers for sources and sinks
        for i, row in df_source.iterrows():
            folium.Marker(
                location=(row['lat'], row['lon']),
                icon=folium.Icon(color='blue'),
                tooltip=f"source_{int(row['id'])}"
            ).add_to(map)
        
        for i, row in df_sink.iterrows():
            folium.Marker(
                location=(row['latitude'], row['longitude']),
                icon=folium.Icon(color='red'),
                tooltip=f"sink_{int(row['id'])}"
            ).add_to(map)

        # Add flow paths
        map = visualize_flow_map(map, df_source, df_sink, path_registry, path_vars)

        # Save or display the map 
        map.save("/Users/samuele/Desktop/我/CC/FoliaStream/test_dikstra/map.html")
        
if __name__ == "__main__":
    main()
# Out:
# {447843: Flow_from_447843_to_atmo, 25450642: Flow_from_25450642_to_atmo, 25451328: Flow_from_25451328_to_atmo, 448783: Flow_from_448783_to_atmo, 449710: Flow_from_449710_to_atmo, 25450244: Flow_from_25450244_to_atmo, 447453: Flow_from_447453_to_atmo, 447456: Flow_from_447456_to_atmo, 25450561: Flow_from_25450561_to_atmo, 447762: Flow_from_447762_to_atmo, 25450608: Flow_from_25450608_to_atmo, 25452738: Flow_from_25452738_to_atmo, 25452723: Flow_from_25452723_to_atmo, 25452187: Flow_from_25452187_to_atmo, 25452991: Flow_from_25452991_to_atmo, 25453551: Flow_from_25453551_to_atmo, 25452183: Flow_from_25452183_to_atmo, 447847: Flow_from_447847_to_atmo, 25453669: Flow_from_25453669_to_atmo, 25453589: Flow_from_25453589_to_atmo, 449699: Flow_from_449699_to_atmo, 25450666: Flow_from_25450666_to_atmo, 25454624: Flow_from_25454624_to_atmo, 449388: Flow_from_449388_to_atmo, 25454799: Flow_from_25454799_to_atmo, 717512: Flow_from_717512_to_atmo, 25454798: Flow_from_25454798_to_atmo, 450208: Flow_from_450208_to_atmo, 450725: Flow_from_450725_to_atmo, 450842: Flow_from_450842_to_atmo, 25452181: Flow_from_25452181_to_atmo, 453081: Flow_from_453081_to_atmo, 451303: Flow_from_451303_to_atmo, 451828: Flow_from_451828_to_atmo, 451072: Flow_from_451072_to_atmo, 25451591: Flow_from_25451591_to_atmo, 448761: Flow_from_448761_to_atmo, 718131: Flow_from_718131_to_atmo, 25453118: Flow_from_25453118_to_atmo, 25453334: Flow_from_25453334_to_atmo, 25453085: Flow_from_25453085_to_atmo, 25455898: Flow_from_25455898_to_atmo, 447380: Flow_from_447380_to_atmo, 450987: Flow_from_450987_to_atmo, 449259: Flow_from_449259_to_atmo, 25454893: Flow_from_25454893_to_atmo, 25454212: Flow_from_25454212_to_atmo, 25453227: Flow_from_25453227_to_atmo, 25454432: Flow_from_25454432_to_atmo, 449123: Flow_from_449123_to_atmo, 25451223: Flow_from_25451223_to_atmo, 453092: Flow_from_453092_to_atmo, 450248: Flow_from_450248_to_atmo, 452075: Flow_from_452075_to_atmo, 450426: Flow_from_450426_to_atmo, 25457296: Flow_from_25457296_to_atmo, 449555: Flow_from_449555_to_atmo, 451022: Flow_from_451022_to_atmo, 449968: Flow_from_449968_to_atmo, 25454664: Flow_from_25454664_to_atmo, 447862: Flow_from_447862_to_atmo, 25455838: Flow_from_25455838_to_atmo, 25453228: Flow_from_25453228_to_atmo, 452104: Flow_from_452104_to_atmo, 448819: Flow_from_448819_to_atmo, 25454426: Flow_from_25454426_to_atmo, 25451651: Flow_from_25451651_to_atmo, 25453662: Flow_from_25453662_to_atmo, 25454667: Flow_from_25454667_to_atmo, 25452188: Flow_from_25452188_to_atmo, 25451001: Flow_from_25451001_to_atmo, 452487: Flow_from_452487_to_atmo, 25451527: Flow_from_25451527_to_atmo, 25453444: Flow_from_25453444_to_atmo, 447807: Flow_from_447807_to_atmo, 25453371: Flow_from_25453371_to_atmo, 25452960: Flow_from_25452960_to_atmo, 25452138: Flow_from_25452138_to_atmo, 25454255: Flow_from_25454255_to_atmo, 25451652: Flow_from_25451652_to_atmo, 25450663: Flow_from_25450663_to_atmo, 25454813: Flow_from_25454813_to_atmo, 25452809: Flow_from_25452809_to_atmo, 25452493: Flow_from_25452493_to_atmo, 25451440: Flow_from_25451440_to_atmo, 25450878: Flow_from_25450878_to_atmo, 451227: Flow_from_451227_to_atmo, 25450665: Flow_from_25450665_to_atmo, 25454259: Flow_from_25454259_to_atmo, 25451564: Flow_from_25451564_to_atmo, 25455135: Flow_from_25455135_to_atmo, 25451568: Flow_from_25451568_to_atmo, 25452674: Flow_from_25452674_to_atmo, 448072: Flow_from_448072_to_atmo, 25450664: Flow_from_25450664_to_atmo, 452414: Flow_from_452414_to_atmo, 25453142: Flow_from_25453142_to_atmo, 25452649: Flow_from_25452649_to_atmo, 25452186: Flow_from_25452186_to_atmo, 25452898: Flow_from_25452898_to_atmo, 25453143: Flow_from_25453143_to_atmo, 25450645: Flow_from_25450645_to_atmo, 450892: Flow_from_450892_to_atmo, 25450643: Flow_from_25450643_to_atmo, 25452492: Flow_from_25452492_to_atmo, 25454666: Flow_from_25454666_to_atmo, 25455268: Flow_from_25455268_to_atmo, 447845: Flow_from_447845_to_atmo, 25450916: Flow_from_25450916_to_atmo, 25452560: Flow_fr ...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2d/n_vsfm_n1_l_wtnsx7bt2g300000gn/T/ec92cc6e0cca408a87b0276f1560fbe6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2d/n_vsfm_n1_l_wtnsx7bt2g300000gn/T/ec92cc6e0cca408a87b0276f1560fbe6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 20865 COLUMNS
# At line 196239 RHS
# At line 217100 BOUNDS
# At line 289217 ENDATA
# Problem MODEL has 20860 rows, 82546 columns and 103257 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7560 (-13300) rows, 59564 (-22982) columns and 66989 (-36268) elements
# 0  Obj 0 Primal inf 1.4428617e+08 (135)
# 226  Obj 0 Primal inf 1.4428617e+08 (135)
# 452  Obj 2.4419174e+09 Primal inf 1.0367437e+08 (132)
# 678  Obj 5.6309974e+09 Primal inf 50979973 (125)
# 904  Obj 5.9598588e+09 Primal inf 37080373 (122)
# 1130  Obj 6.1349097e+09 Primal inf 29618173 (119)
# 1356  Obj 6.1541864e+09 Primal inf 27780473 (118)
# 1582  Obj 6.2167783e+09 Primal inf 26673213 (117)
# 1808  Obj 6.2911418e+09 Primal inf 25666113 (116)
# 2034  Obj 6.4011816e+09 Primal inf 21377813 (111)
# 2260  Obj 6.484766e+09 Primal inf 17690473 (106)
# 2486  Obj 6.4960794e+09 Primal inf 16413323 (104)
# 2712  Obj 6.5568808e+09 Primal inf 14193343 (100)
# 2938  Obj 6.6034865e+09 Primal inf 12785103 (97)
# 3164  Obj 6.6259802e+09 Primal inf 11106133 (93)
# 3390  Obj 6.6874988e+09 Primal inf 10028683 (90)
# 3616  Obj 6.7612905e+09 Primal inf 9062453.5 (87)
# 3842  Obj 6.8233914e+09 Primal inf 7644143.5 (82)
# 4068  Obj 6.9163687e+09 Primal inf 6131973.5 (76)
# 4294  Obj 6.9584753e+09 Primal inf 5261333.5 (72)
# 4520  Obj 6.9977123e+09 Primal inf 4672733.5 (69)
# 4746  Obj 7.0307696e+09 Primal inf 3841263.5 (64)
# 4972  Obj 7.0622315e+09 Primal inf 3399613.5 (61)
# 5198  Obj 7.1124635e+09 Primal inf 2382197.5 (53)
# 5424  Obj 7.1463877e+09 Primal inf 1953729.5 (49)
# 5650  Obj 7.1647725e+09 Primal inf 1524101.5 (44)
# 5876  Obj 7.1903444e+09 Primal inf 1224789.5 (40)
# 6102  Obj 7.1959325e+09 Primal inf 1111239.5 (38)
# 6328  Obj 7.2048846e+09 Primal inf 948071.5 (35)
# 6554  Obj 7.2269342e+09 Primal inf 647610.5 (28)
# 6780  Obj 7.2337914e+09 Primal inf 538901.5 (25)
# 7006  Obj 7.2417178e+09 Primal inf 414359.5 (21)
# 7232  Obj 7.2588521e+09 Primal inf 213654.5 (13)
# 7458  Obj 7.2637469e+09 Primal inf 101419.5 (7)
# 7560  Obj 7.2705336e+09
# Optimal - objective value 7.2705336e+09
# After Postsolve, objective 7.2705336e+09, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7270533608 - 7560 iterations time 0.132, Presolve 0.07
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.26   (Wallclock seconds):       0.30
#
# Status:  Optimal
#
#  Flow Results:
# Flow from source_447843 to sink_10030: 15155000.00 tons
# Path: source_447843==>source_447762==>source_25453669==>source_449259==>source_448072==>source_25450305==>source_447847==>sink_10030
# Distance: 356.93 km
#
# Flow from source_25450642 to sink_10030: 13890000.00 tons
# Path: source_25450642==>source_25450645==>source_447845==>source_25454016==>source_447843==>source_447762==>source_25453669==>source_449259==>source_448072==>source_25450305==>sink_10030
# Distance: 436.55 km
#
# Flow from source_25451328 to sink_10063: 11566800.00 tons
# Path: source_25451328==>source_25450608==>source_25453085==>sink_10063
# Distance: 63.68 km
#
# Flow from source_448783 to sink_10059: 8820400.00 tons
# Path: source_448783==>source_25457296==>source_447453==>sink_10059
# Distance: 333.19 km
#
# Flow from source_449710 to sink_10063: 7536200.00 tons
# Path: source_449710==>source_25452649==>source_25451328==>source_25450608==>sink_10063
# Distance: 86.11 km
#
# Flow from source_25450244 to sink_10025: 7484400.00 tons
# Path: source_25450244==>source_25457296==>source_448783==>sink_10025
# Distance: 421.26 km
#
# Flow from source_447453 to sink_10025: 7446400.00 tons
# Path: source_447453==>source_25450244==>sink_10025
# Distance: 335.27 km
#
# Flow from source_447456 to sink_10056: 7438300.00 tons
# Path: source_447456==>source_25452991==>source_25453662==>source_25454799==>source_450725==>source_25452723==>source_451072==>sink_10056
# Distance: 241.20 km
#
# Flow from source_25450561 to sink_10030: 7038400.00 tons
# Path: source_25450561==>source_449259==>source_25450877==>source_447847==>sink_10030
# Distance: 351.30 km
#
# Flow from source_447762 to sink_10030: 6930300.00 tons
# Path: source_447762==>source_25453669==>source_449259==>source_25450877==>source_448072==>source_25450305==>source_447847==>sink_10030
# Distance: 352.27 km
#
# Flow from source_25450608 to sink_10063: 5341600.00 tons
# Path: source_25450608==>source_25453085==>source_25451328==>sink_10063
# Distance: 65.05 km
#
# Flow from source_25452738 to sink_10020: 4620200.00 tons
# Path: source_25452738==>sink_10020
# Distance: 146.54 km
#
# Flow from source_25452723 to sink_10056: 3937800.00 tons
# Path: source_25452723==>source_25454799==>source_25454798==>source_451072==>sink_10056
# Distance: 157.39 km
#
# Flow from source_25452187 to sink_10066: 2974400.00 tons
# Path: source_25452187==>source_25452183==>source_25453551==>source_449699==>sink_10066
# Distance: 64.65 km
#
# Flow from source_25452991 to sink_10056: 2336400.00 tons
# Path: source_25452991==>source_447456==>source_25453662==>source_25454799==>source_450725==>source_25452723==>source_451072==>sink_10056
# Distance: 241.07 km
#
# Flow from source_25453551 to sink_10066: 2151400.00 tons
# Path: source_25453551==>source_25452183==>source_449699==>sink_10066
# Distance: 55.65 km
#
# Flow from source_25452183 to sink_10066: 1837700.00 tons
# Path: source_25452183==>source_25453551==>source_449699==>sink_10066
# Distance: 52.45 km
#
# Flow from source_447847 to sink_10030: 1107260.00 tons
# Path: source_447847==>source_25450305==>source_448072==>source_25450877==>sink_10030
# Distance: 282.64 km
#
# Flow from source_25453669 to sink_10030: 1007100.00 tons
# Path: source_25453669==>source_447762==>source_447843==>source_449259==>source_448072==>source_25450305==>source_447847==>sink_10030
# Distance: 369.20 km
#
# Flow from source_25453589 to sink_10015: 923660.00 tons
# Path: source_25453589==>sink_10015
# Distance: 174.48 km
#
# Flow from source_449699 to sink_10066: 896250.00 tons
# Path: source_449699==>sink_10066
# Distance: 30.91 km
#
# Flow from source_25450666 to sink_10017: 834620.00 tons
# Path: source_25450666==>source_25454432==>source_25454491==>source_448819==>source_447862==>source_25453113==>source_452414==>sink_10017
# Distance: 313.91 km
#
# Flow from source_25454624 to sink_10028: 820700.00 tons
# Path: source_25454624==>sink_10028
# Distance: 4.94 km
#
# Flow from source_449388 to sink_10029: 813070.00 tons
# Path: source_449388==>source_718131==>sink_10029
# Distance: 117.18 km
#
# Flow from source_25454799 to sink_10056: 784530.00 tons
# Path: source_25454799==>source_25454798==>source_450725==>source_25452723==>source_451072==>sink_10056
# Distance: 133.66 km
#
# Flow from source_717512 to sink_10031: 765080.00 tons
# Path: source_717512==>sink_10031
# Distance: 52.44 km
#
# Flow from source_25454798 to sink_10056: 721960.00 tons
# Path: source_25454798==>source_25454799==>source_450725==>source_25452723==>source_451072==>sink_10056
# Distance: 133.79 km
#
# Flow from source_450208 to sink_10019: 709440.00 tons
# Path: source_450208==>source_25453118==>sink_10019
# Distance: 110.44 km
#
# Flow from source_450725 to sink_10056: 706330.00 tons
# Path: source_450725==>source_25454798==>source_25454799==>source_25453662==>source_25452723==>source_451072==>sink_10056
# Distance: 138.73 km
#
# Flow from source_450842 to sink_10066: 665100.00 tons
# Path: source_450842==>sink_10066
# Distance: 14.32 km
#
# Flow from source_25452181 to sink_10063: 612050.00 tons
# Path: source_25452181==>source_25451328==>source_25450608==>sink_10063
# Distance: 76.86 km
#
# Flow from source_453081 to sink_10022: 568370.00 tons
# Path: source_453081==>source_4407799==>source_4405978==>source_25454331==>sink_10022
# Distance: 258.56 km
#
# Flow from source_451303 to sink_10028: 566380.00 tons
# Path: source_451303==>source_25454624==>sink_10028
# Distance: 85.52 km
#
# Flow from source_451828 to sink_10004: 547580.00 tons
# Path: source_451828==>source_448761==>sink_10004
# Distance: 148.47 km
#
# Flow from source_451072 to sink_10056: 537650.00 tons
# Path: source_451072==>sink_10056
# Distance: 50.81 km
#
# Flow from source_25451591 to sink_10056: 481290.00 tons
# Path: source_25451591==>source_25454798==>source_450725==>source_25452723==>source_451072==>sink_10056
# Distance: 217.35 km
#
# Flow from source_448761 to sink_10004: 467920.00 tons
# Path: source_448761==>source_451828==>source_25451564==>sink_10004
# Distance: 171.27 km
#
# Flow from source_718131 to sink_10029: 459030.00 tons
# Path: source_718131==>source_449388==>sink_10029
# Distance: 105.19 km
#
# Flow from source_25453118 to sink_10019: 433990.00 tons
# Path: source_25453118==>source_450208==>source_25450876==>sink_10019
# Distance: 140.46 km
#
# Flow from source_25453334 to sink_10066: 431230.00 tons
# Path: source_25453334==>sink_10066
# Distance: 16.03 km
#
# Flow from source_25453085 to sink_10063: 417300.00 tons
# Path: source_25453085==>source_25450608==>source_25451328==>sink_10063
# Distance: 64.85 km
#
# Flow from source_25455898 to sink_10066: 396450.00 tons
# Path: source_25455898==>source_450842==>sink_10066
# Distance: 44.23 km
#
# Flow from source_450987 to sink_10066: 365580.00 tons
# Path: source_450987==>source_450426==>source_453092==>source_25454667==>source_25455898==>source_450842==>sink_10066
# Distance: 97.09 km
#
# Flow from source_449259 to sink_10030: 344780.00 tons
# Path: source_449259==>source_25450877==>source_448072==>source_25450305==>source_447847==>sink_10030
# Distance: 256.84 km
#
# Flow from source_25454212 to sink_10028: 319950.00 tons
# Path: source_25454212==>source_25451001==>source_25454664==>source_25451223==>source_25454624==>sink_10028
# Distance: 167.01 km
#
# Flow from source_25453227 to sink_10017: 306860.00 tons
# Path: source_25453227==>source_25450663==>source_25455838==>source_449968==>source_450248==>source_25454432==>source_25450666==>source_714825==>source_447862==>source_25453113==>source_452414==>sink_10017
# Distance: 475.18 km
#
# Flow from source_25454432 to sink_10017: 293510.00 tons
# Path: source_25454432==>source_25450666==>source_714825==>source_447862==>source_25453113==>source_452414==>sink_10017
# Distance: 310.78 km
#
# Flow from source_449123 to sink_10028: 288340.00 tons
# Path: source_449123==>source_25454259==>source_25454212==>source_451303==>sink_10028
# Distance: 197.60 km
#
# Flow from source_25451223 to sink_10028: 286970.00 tons
# Path: source_25451223==>source_25454664==>source_25451001==>source_25454212==>source_451303==>sink_10028
# Distance: 175.56 km
#
# Flow from source_453092 to sink_10066: 278230.00 tons
# Path: source_453092==>source_450426==>source_450987==>source_25454667==>source_25455898==>source_450842==>sink_10066
# Distance: 96.72 km
#
# Flow from source_450248 to sink_10017: 271260.00 tons
# Path: source_450248==>source_25454432==>source_25450666==>source_714825==>source_447862==>source_25453113==>source_452414==>sink_10017
# Distance: 313.42 km
#
# Flow from source_452075 to sink_10048: 267170.00 tons
# Path: source_452075==>source_25455135==>source_25452898==>sink_10048
# Distance: 440.29 km
#
# Flow from source_450426 to sink_10066: 260780.00 tons
# Path: source_450426==>source_450987==>source_25454667==>source_25455898==>source_450842==>sink_10066
# Distance: 96.48 km
#
# Flow from source_25457296 to sink_10061: 250390.00 tons
# Path: source_25457296==>source_448783==>source_447453==>sink_10061
# Distance: 336.78 km
#
# Flow from source_451022 to sink_10005: 247600.00 tons
# Path: source_451022==>sink_10005
# Distance: 155.30 km
#
# Flow from source_449968 to sink_10017: 237850.00 tons
# Path: source_449968==>source_25455838==>source_450248==>source_25454432==>source_25450666==>source_714825==>source_447862==>source_25453113==>source_452414==>sink_10017
# Distance: 315.85 km
#
# Flow from source_25454664 to sink_10028: 227870.00 tons
# Path: source_25454664==>source_25451001==>source_25454212==>source_451303==>sink_10028
# Distance: 172.79 km
#
# Flow from source_447862 to sink_10017: 219900.00 tons
# Path: source_447862==>source_714825==>source_25450666==>source_25454491==>source_449968==>source_25453113==>source_452414==>sink_10017
# Distance: 323.64 km
#
# Flow from source_25455838 to sink_10017: 214210.00 tons
# Path: source_25455838==>source_449968==>source_450248==>source_25454432==>source_25450666==>source_714825==>source_447862==>source_25453113==>source_452414==>sink_10017
# Distance: 315.84 km
#
# Flow from source_25453228 to sink_10019: 208660.00 tons
# Path: source_25453228==>source_450208==>source_25450876==>sink_10019
# Distance: 154.96 km
#
# Flow from source_448819 to sink_10017: 203170.00 tons
# Path: source_448819==>source_25454491==>source_25450666==>source_714825==>source_447862==>source_25453113==>source_452414==>sink_10017
# Distance: 311.96 km
#
# Flow from source_25454426 to sink_10004: 182210.00 tons
# Path: source_25454426==>source_451828==>source_25451564==>sink_10004
# Distance: 171.19 km
#
# Flow from source_25453662 to sink_10056: 175560.00 tons
# Path: source_25453662==>source_25454799==>source_25454798==>source_450725==>source_25452723==>source_451072==>sink_10056
# Distance: 138.29 km
#
# Flow from source_25454667 to sink_10066: 166930.00 tons
# Path: source_25454667==>source_447807==>source_450987==>source_450426==>source_453092==>source_25455898==>source_450842==>sink_10066
# Distance: 100.61 km
#
# Flow from source_25452188 to sink_10036: 157320.00 tons
# Path: source_25452188==>sink_10036
# Distance: 40.23 km
#
# Flow from source_25451001 to sink_10028: 155000.00 tons
# Path: source_25451001==>source_25454664==>source_25451223==>source_25454259==>source_451303==>sink_10028
# Distance: 190.67 km
#
# Flow from source_452487 to sink_10014: 150810.00 tons
# Path: source_452487==>source_25451652==>sink_10014
# Distance: 285.45 km
#
# Flow from source_25453444 to sink_10021: 144780.00 tons
# Path: source_25453444==>sink_10021
# Distance: 284.79 km
#
# Flow from source_447807 to sink_10066: 134030.00 tons
# Path: source_447807==>source_450987==>source_450426==>source_453092==>source_25455898==>source_450842==>sink_10066
# Distance: 99.41 km
#
# Flow from source_25453371 to sink_10020: 131270.00 tons
# Path: source_25453371==>sink_10020
# Distance: 245.77 km
#
# Flow from source_25452960 to sink_10064: 127980.00 tons
# Path: source_25452960==>sink_10064
# Distance: 35.72 km
#
# Flow from source_25452138 to sink_10061: 127040.00 tons
# Path: source_25452138==>sink_10061
# Distance: 74.05 km
#
# Flow from source_25451652 to sink_10014: 125197.00 tons
# Path: source_25451652==>source_452487==>sink_10014
# Distance: 285.87 km
#
# Flow from source_25450663 to sink_10017: 125197.00 tons
# Path: source_25450663==>source_25455838==>source_449968==>source_450248==>source_25454432==>source_25450666==>source_25453113==>source_452414==>sink_10017
# Distance: 409.92 km
#
# Flow from source_25454813 to sink_10028: 120242.00 tons
# Path: source_25454813==>source_25454259==>source_25454212==>source_25454624==>sink_10028
# Distance: 343.09 km
#
# Flow from source_25452809 to sink_10017: 111282.00 tons
# Path: source_25452809==>source_25450665==>sink_10017
# Distance: 99.10 km
#
# Flow from source_451227 to sink_10025: 87637.00 tons
# Path: source_451227==>source_25453701==>source_25453143==>source_25453142==>sink_10025
# Distance: 257.72 km
#
# Flow from source_25450665 to sink_10017: 87637.00 tons
# Path: source_25450665==>sink_10017
# Distance: 59.29 km
#
# Flow from source_25454259 to sink_10028: 85450.00 tons
# Path: source_25454259==>source_25454212==>source_25451001==>source_25454624==>sink_10028
# Distance: 161.64 km
#
# Flow from source_25451564 to sink_10004: 85442.00 tons
# Path: source_25451564==>source_451828==>source_448761==>sink_10004
# Distance: 158.79 km
#
# Flow from source_25455135 to sink_10048: 83462.00 tons
# Path: source_25455135==>source_452075==>source_25452898==>sink_10048
# Distance: 440.47 km
#
# Flow from source_448072 to sink_10030: 75115.00 tons
# Path: source_448072==>source_25450305==>source_447847==>sink_10030
# Distance: 209.82 km
#
# Flow from source_452414 to sink_10017: 57635.00 tons
# Path: source_452414==>source_25453113==>source_714825==>source_25454432==>source_450248==>source_449968==>sink_10017
# Distance: 346.20 km
#
# Flow from source_25453142 to sink_10025: 55915.00 tons
# Path: source_25453142==>source_25453143==>sink_10025
# Distance: 142.85 km
#
# Flow from source_25452649 to sink_10063: 55642.00 tons
# Path: source_25452649==>source_25451328==>source_25450608==>sink_10063
# Distance: 77.01 km
#
# Flow from source_25452898 to sink_10048: 53082.00 tons
# Path: source_25452898==>sink_10048
# Distance: 249.67 km
#
# Flow from source_25453143 to sink_10025: 44511.00 tons
# Path: source_25453143==>source_25453142==>sink_10025
# Distance: 137.93 km
#
# Flow from source_25450645 to sink_10030: 44335.00 tons
# Path: source_25450645==>source_25450642==>source_25454016==>source_447843==>source_447762==>source_25453669==>source_449259==>source_448072==>source_25450305==>sink_10030
# Distance: 435.41 km
#
# Flow from source_450892 to sink_10017: 44335.00 tons
# Path: source_450892==>source_450248==>source_25454432==>source_25450666==>source_25453113==>source_452414==>sink_10017
# Distance: 364.95 km
#
# Flow from source_25450643 to sink_10024: 44335.00 tons
# Path: source_25450643==>sink_10024
# Distance: 161.32 km
#
# Flow from source_447845 to sink_10030: 39016.00 tons
# Path: source_447845==>source_25450645==>source_25450642==>source_25454016==>source_447843==>source_447762==>source_25453669==>source_449259==>source_448072==>source_25450305==>sink_10030
# Distance: 437.67 km
#
# Flow from source_25450916 to sink_10063: 35196.00 tons
# Path: source_25450916==>sink_10063
# Distance: 25.50 km
#
# Flow from source_25452560 to sink_10028: 34497.00 tons
# Path: source_25452560==>source_25454813==>source_25454259==>source_25451001==>source_25454624==>sink_10028
# Distance: 472.84 km
#
# Flow from source_25451566 to sink_10003: 32010.00 tons
# Path: source_25451566==>source_25451567==>sink_10003
# Distance: 322.77 km
#
# Flow from source_25451569 to sink_10008: 31920.00 tons
# Path: source_25451569==>sink_10008
# Distance: 362.78 km
#
# Flow from source_25450877 to sink_10030: 30463.00 tons
# Path: source_25450877==>source_448072==>source_25450305==>source_447847==>sink_10030
# Distance: 236.37 km
#
# Flow from source_25450243 to sink_10025: 30149.00 tons
# Path: source_25450243==>source_4404167==>source_25452644==>source_25453143==>sink_10025
# Distance: 348.94 km
#
# Flow from source_25454491 to sink_10017: 26779.00 tons
# Path: source_25454491==>source_448819==>source_25450666==>source_714825==>source_447862==>source_25453113==>source_452414==>sink_10017
# Distance: 312.00 km
#
# Flow from source_25453443 to sink_10006: 26600.00 tons
# Path: source_25453443==>sink_10006
# Distance: 284.59 km
#
# Flow from source_25454665 to sink_10028: 24829.00 tons
# Path: source_25454665==>source_25454666==>source_25454813==>source_451303==>sink_10028
# Distance: 490.07 km
#
# Flow from source_25451567 to sink_10004: 22586.00 tons
# Path: source_25451567==>source_25454426==>source_451828==>source_25451564==>sink_10004
# Distance: 337.49 km
#
# Flow from source_25450305 to sink_10030: 20448.00 tons
# Path: source_25450305==>source_448072==>source_447847==>sink_10030
# Distance: 211.78 km
#
# Flow from source_25453741 to sink_10010: 20262.00 tons
# Path: source_25453741==>sink_10010
# Distance: 128.68 km
#
# Flow from source_25452185 to sink_10065: 18444.00 tons
# Path: source_25452185==>sink_10065
# Distance: 59.49 km
#
# Flow from source_25453825 to sink_10069: 17805.00 tons
# Path: source_25453825==>sink_10069
# Distance: 352.25 km
#
# Flow from source_714825 to sink_10017: 17805.00 tons
# Path: source_714825==>source_25450666==>source_25454491==>source_449968==>source_25453113==>source_452414==>sink_10017
# Distance: 320.17 km
#
# Flow from source_25453701 to sink_10025: 17471.00 tons
# Path: source_25453701==>source_451227==>source_25453143==>source_25453142==>sink_10025
# Distance: 255.67 km
#
# Flow from source_25453113 to sink_10017: 15961.00 tons
# Path: source_25453113==>source_452414==>source_714825==>source_25454432==>source_450248==>source_449968==>sink_10017
# Distance: 346.25 km
#
# Flow from source_25450876 to sink_10019: 15302.00 tons
# Path: source_25450876==>source_450208==>source_25453118==>sink_10019
# Distance: 133.54 km
#
# Flow from source_25453355 to sink_10021: 15289.00 tons
# Path: source_25453355==>sink_10021
# Distance: 230.68 km
#
# Flow from source_25454016 to sink_10030: 13994.00 tons
# Path: source_25454016==>source_25450645==>source_25450642==>source_447843==>source_447762==>source_25453669==>source_449259==>source_448072==>source_25450305==>sink_10030
# Distance: 449.40 km
#
# Flow from source_25452182 to sink_10021: 12334.50 tons
# Path: source_25452182==>sink_10021
# Distance: 184.72 km
#
# Emissions from source_447380 to atmosphere: 367090.00 units
# Emissions from source_25454893 to atmosphere: 339420.00 units
# Emissions from source_449555 to atmosphere: 248380.00 units
# Emissions from source_452104 to atmosphere: 203220.00 units
# Emissions from source_25451651 to atmosphere: 176660.00 units
# Emissions from source_25451527 to atmosphere: 146060.00 units
# Emissions from source_25454255 to atmosphere: 126460.00 units
# Emissions from source_25452493 to atmosphere: 107543.00 units
# Emissions from source_25451440 to atmosphere: 106847.00 units
# Emissions from source_25450878 to atmosphere: 102796.00 units
# Emissions from source_25451568 to atmosphere: 79134.00 units
# Emissions from source_25452674 to atmosphere: 75512.00 units
# Emissions from source_25450664 to atmosphere: 69551.00 units
# Emissions from source_25452186 to atmosphere: 54444.00 units
# Emissions from source_25452492 to atmosphere: 41730.00 units
# Emissions from source_25454666 to atmosphere: 40790.00 units
# Emissions from source_25455268 to atmosphere: 40425.00 units
# Emissions from source_25452491 to atmosphere: 27633.00 units
# Emissions from source_25453521 to atmosphere: 25676.00 units
# Emissions from source_25453522 to atmosphere: 23650.00 units
# Emissions from source_25452618 to atmosphere: 22952.00 units
# Emissions from source_25451570 to atmosphere: 15903.00 units
# Emissions from source_25452184 to atmosphere: 12636.00 units
#
#  Total Cost: 7270533608.382181

# %% [markdown]
# # Additional functions

# %%
# Custom dijkstra implementation that avoids specified node types
def path_dependent_dijkstra_with_exclusions(G, source, target, exclude_types=None):
    
    if exclude_types is None:
        exclude_types = []
    
    # Track distances, paths, and hop counts
    distances = {node: float('infinity') for node in G.nodes()}
    distances[source] = 0
    previous_nodes = {node: None for node in G.nodes()}
    hop_counts = {node: 0 for node in G.nodes()}
    hop_counts[source] = 1

    # Priority queue for nodes to visit: (adjusted_distance, node)
    priority_queue = [(0, source)]

    while priority_queue:
        current_distance, current_node = heapq.heappop(priority_queue)

        # Stop if we reached the target
        if current_node == target:
            break
        
        # Skip if already found better path
        if current_distance > distances[current_node]:
            continue

        # Check all neighbors
        for neighbor in G.neighbors(current_node):
            # Skip excluded node types (except target)
            if neighbor != target and G.nodes[neighbor].get('type') in exclude_types:
                continue
            
            # Raw edge weight
            edge_weight = G[current_node][neighbor]['weight']

            # Adjust weight based on hop count (divide by hop count)
            adjusted_weight = edge_weight / hop_counts[current_node]

            # Calculate new distance
            distance = distances[current_node] + adjusted_weight

            # Update if better path found 
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                previous_nodes[neighbor] = current_node
                hop_counts[neighbor] = hop_counts[current_node] + 1
                heapq.heappop(priority_queue, (distance, neighbor))

    # Reconstruct path 
    path = []
    current_node = target
    while current_node is not None:
        path.insert(0, current_node)
        current_node = previous_nodes[current_node]
    
    # Check if path exists
    if path[0] != source:
        return [], float('infinity'), float('infinity'), 0
    
    # Calculate actual distance (not adjusted) for the found path
    actual_distance = 0
    for i in range(len(path) - 1):
        actual_distance += G[path[i]][path[i+1]]['weight']
    
    return path, distances[target], actual_distance, hop_counts[target]

# %%
# Find path that must go through specific waypoints without using sink nodes in intermediate segments

def path_with_required_waypoints(G, source, target, waypoints_df):

    # Get waypoints that must be visited
    source_waypoints = waypoints_df[waypoints_df['id'] == source]['waypoint_id'].to_list()

    if not source_waypoints:
        # No required waypoints --> find direct path
        return path_dependent_dijkstra(G, source, target)
    
    # Add target as the final destination
    ordered_stops = source_waypoints + [target]

    # Initialize
    complete_path = []
    total_adjusted_distance = 0
    total_actual_distance = 0
    current = source
    hop_count = 1

    # Find path segments through each waypoint in sequence
    for i, next_stop in enumerate(ordered_stops):

        # Avoid sink nodes except last one
        if i < len(ordered_stops) - 1:
            segment_path, semgent_adjusted, segment_actual, segment_hops = path_dependent_dijkstra_with_exclusions(G, current, next_stop, exclude_types=['sink'])
        else:
            # Normal dijkstra for last segment (final sink)
            segment_path, semgent_adjusted, segment_actual, segment_hops = path_dependent_dijkstra(G, current, next_stop)

        # Check if a path was found
        if not segment_path:
            print(f"No valit path found from {current} to {next_stop} with given constraints")
            return [], 0, 0, 0

        # Add segment to complete path (avoid duplicates)
        if complete_path:
            complete_path.extend(segment_path[1:]) # Skip first node to avoid duplication
        else:
            complete_path = segment_path

        # Update metrics
        total_adjusted_distance += semgent_adjusted
        total_actual_distance += segment_actual
        hop_count = len(complete_path)

        # Update current position
        current = next_stop

    return complete_path, total_adjusted_distance, total_actual_distance, hop_count

# %%
def calculate_distance(node1, node2):
    return math.sqrt((node2[0] - node1[0]) ** 2 + (node2[1] - node1[1]) ** 2)

# %%
# coordinates = {
#     'Node1':(1,1),
#     'Node2':(2,3),
#     'Node3':(3,5),
#     'Node4':(4,7),
#     'Node5':(5,9),
#     'Node6':(6,11),
#     'Node7':(7,13),
#     'Node8':(8,15),
#     'Node9':(9,17),
#     'Node10':(10,19),
#     'SinkNode1':(15,15),
#     'SinkNode2':(20,20),
# }

# graph = {node: {} for node in coordinates}

# for node1 in coordinates:
#     for node2 in coordinates:
#         if node1 != node2:
#             graph[node1][node2] = calculate_distance(coordinates[node1], coordinates[node2])

# waypoints_df = pd.DataFrame([
#     {'id':447843, 'waypoint_id':25450642}
# ])

# path, adjusted_dist, actual_dist, hops = path_with_required_waypoints(graph, 1, 1, waypoints_df)
